# %% [markdown]
# <div style="background-color: lightgreen; padding: 18px;">
#     <h1> Aula 9| Estatística I
# </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h2> Tópicos da aula 9
# </div>
#
# - Introdução à séries temporais

# %% [markdown]
# 1. Introdução
#
# O objeto das __séries temporais__ é desenvolver modelos matemáticos que descrevam o comportamento de uma variável aleatório ao longo do tempo. Em geral, os modelos utilizados para descrever séries temporais são __processos estocásticos__, onde o processo estocástico em si compõe uma família de variáveis aleatórias e uma realização ou trajetória do processo estocástico pode ser visto como uma __série temporal__.
#
# Os processos estocásticos podem ser **discretos**, por exemplo, o número de chamadas telefônicas que chega a uma central em cinco horas, ou **contínuo**, por exemplo o preço de uma ação na bolsa de valores.
#
# Pode-se descrever um processo estocástico por meio da distribuição de probabilidade conjunta de $Z(t_1),\ldots,Z(t_k)$, mas aqui será abordado o assunto de uma forma um pouco mais simples. Portanto utilizando as funções para o caso contínuo, têm-se que:
#
# - Média: $\mu(t) = E(Z(t))$
#
# - Variância: $\sigma^2(t) = Var(Z(t))$
#
# <br>
#
# Alguns exemplos de processos estocásticos serão definidos nos tópicos a seguir, sendo eles:
#
# <br>
#
#  - Sequência Aleatória;
#  - Ruído branco (_White-Noise_);
#  - Passeio Aleatório (_Random Walk_).
#
# <br><br>
#
# ### 1.1 Sequência Aleatória
#
# <br>
#
# Considere $\{X_n,n=1,2,\ldots\}$ uma sequência de variável aleatória definidas no mesmo espaço amostral $\Omega$. Aqui, $\mathcal{T}=\{1,2,\ldots\}$ e tem-se um processo com parâmetro discreto, ou uma sequência aleatória. Para todo $n\geq 1$, podemos escrever
#
# $$P(X_1=a_1,\ldots,X_n=a_n) = P(X_1=a_1)P(X_2=a_2|X_1=a_1)\ldots P(X_n=a_n|X_1=a_1,\ldots,X_{n-1}=a_{n-1})$$
#
# <br><br>
#
#
# ### 1.2 Ruído Branco (_White-Noise_)
#
# <br>
#
# Pode-se definir um ruído branco como $\{\epsilon_t,t\in \mathbb{Z}\}$ se as variáveis aleatórias $\epsilon_t$ são não-correlacionadas, isto é, se $Cov\{\epsilon_t,\epsilon_s\}=0$ para $t\neq s$.
#
# Esse processo será estacionário (ou seja, a média e a variância não se alteram ao longo do tempo) se $E(\epsilon_t)=\mu_\epsilon$ e $Var(\epsilon_t)=\sigma^2_\epsilon$ para todo $t$.
#
# <br><br>
#
# ### 1.3 Passeio Aleatório (_Random Walk_)
#
# Considere uma sequência aleatória $\{\epsilon_t,t\geq 1\}$ de v.a. i.i.d $(\mu_\epsilon,\sigma^2_\epsilon)$. Defina a sequência
#
# $$X_t = \epsilon_1 + \ldots + \epsilon_t .$$
#
# Segue que
#
# $E(X_t) = t \mu_\epsilon$ e $Var(X_t ) = t\sigma^2_\epsilon$, ou seja, ambos dependem de $t$.
#
# Esse processo é chamado de passeio aleatório e é claramente não estacionário (média e variância se alteram ao longo do tempo).
#
# <br><br>
#
# ## 2. Definição de Séries Temporais
#
# <br>
#
# Uma série temporal pode ser considerado como uma sequência $Z(t_1),Z(t_2),\ldots,Z(t_n)$ observada nos instantes $t_1,\ldots,t_n$, ou seja, uma realização ou trajetória de um processo estocástico. Ao utilizar séries temporais têm-se diversos objetivos como por exemplo investigar o fenômeno gerador da série, descrever o comportamento da série, procurar periodicidades relevantes nos dados ou menos fazer previsões de valores futuros.
#
# As séries temporais podem ser **contínuas**, quando as observações são feitas continuamente no tempo. Nesse caso,
#
# <br>
#
# $$\{Z (t) : t ∈ T \}, T = \{t : t_1 < t < t_2 \}.$$
#
# <br>
#
# Ou podem ser **discretas**, quando as observações são feitas em tempos específicos
#
# <br>
#
# $$\{Z (t) : t ∈ T \}, T = \{t_1 , . . . , t_n \}.$$
#
# <br><br>
#
# ## 3. Componentes da Série Temporal
#
# <br>
#
# Uma série temporal pode ser decomposta nas __componentes__ descritas a seguir:
#
# - **Tendência (T)**: indica o seu comportamento ao longo do tempo, ou seja, se é **crescente**, **decrescente** ou **estável**. Além disso, a tendência indica também a velocidade destas mudanças.
# <br>
# - **Ciclos (C)**: são  **oscilações de subida e de queda nas séries**, de forma **suave e repetida**, ao longo da componente de tendência. Os movimentos cíclicos tendem a ser irregulares.
# <br>
# - **Sazonalidade (S)**: são **oscilações de subida e de queda que sempre ocorrem em um determinado período do ano, do mês, da semana ou do dia**. Estes movimentos são facilmente previsíveis, ocorrendo em **intervalos regulares de tempo**.
# <br>
# - **Ruído Aleatório ($\epsilon$)**: ou erro no período **t** são variações irregulares ou flutuações inexplicáveis, resultado de fatos fortuitos e inesperados.
#
# <br>
#
# Algumas ilustrações:
#
#
# <img src="https://www.researchgate.net/profile/R-Rajput/publication/344658764/figure/fig1/AS:946622322188291@1602703757672/Time-Series-components-1-A-time-series-is-a-sequence-of-observations-measured-at.jpg?resize=661%2C599" width=600>
#
#
#
#
# <br>
#
# Para implementar em _Python_ a decomposição de séries temporais, utiliza-se da função _seasonal_decompose_ oriunda da biblioteca _statsmodels_ (uma das principais bibliotecas a respeito de ferramentas estatísticas):
#
# ````python
# # Carregando a função seasonal_decompose
# from statsmodels.tsa.seasonal import seasonal_decompose
#
# # Aplicando a função seasonal_decompose
# results = seasonal_decompose(df,                  # conjunto de dados da série temporal
#                              model = 'additive',  # tipo de série (aditiva ou multiplicativa
#                              period = 7)          # periodo de tempo da série
#
# # Gera os gráficos da decomposição
# results.plot()
#
# # Mostrar o Gráfico
# plt.show()
# ````
#
#
# ## Séries Aditivas e Multiplicativas
#
# <br>
#
# Note que para a implementação da função _seasonal_decompose_ é necessário conhecer o __período da série temporal__, ou seja o intervalo de tempo entre duas observações (pode ser segundos, minutos, horas, dias e etc.). Além disso, é importante conhecer o tipo de série a ser analisada, podendo ser classificada em 2 tipos principais:
# <br>
# - __Série Aditiva:__ Uma série é considerada __aditiva__ a amplitude da sazonalidade mantém-se constante ao longo do tempo;
#
# <br>
#
# - __Série Multiplicativa:__ Já as série considerada __multiplicativa__, a amplitude da sazonalidade aumenta ao longo do tempo.
#
# <br>
#
# <img src="https://miro.medium.com/max/564/1*LdeXlKrgNkFUjOhnO4Zzaw.jpeg" width=800>
#
# Fonte: [Medium](https://miro.medium.com/max/564/1*LdeXlKrgNkFUjOhnO4Zzaw.jpeg)
#
#
# ### Séries Estacionárias e Não Estacionárias
#
# A diferença entre uma série temporal estacionária e não estacionária é que para as séries estacionárias, o valor de média e variância da série é constante ao longo do tempo, diferente do caso das séries não estacionárias.
#
# <br>
# <img src="https://cdn-images-1.medium.com/max/1600/1*U2m5Eq7ScLnf2kG5mnQsKQ.png" width=800>
# <br>
#
# <br>
#
# <img src="https://miro.medium.com/max/2580/1*tkx0_wwQ2JT7pSlTeg4yzg.png" width=800>
# <br>
#
# Uma forma para sabermos de fato se a nossa série temporal condiz com a condição de ser estacionária, utilizaremos um teste de hipótese chamado de __Teste de Dickey-Fuller Aumentado__.

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import numpy as np

# %%
df_clima = pd.read_csv('clima_india.csv')
df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df_clima
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df_clima.set_index(df_clima.date, inplace=True)

# %%
df_clima
# Out:
#                   date   meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02  2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03  2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04  2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05  2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...                ...        ...         ...         ...           ...
# 2016-12-28  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))
df_clima['humidity'].plot()
plt.grid()

# %%
plt.figure(figsize=(14, 7))
df_clima['meantemp'].plot()
plt.grid()

# %%
plt.figure(figsize=(14, 7))
df_clima['wind_speed'].plot()
plt.figure(figsize=(14, 7))
plt.grid()

# %%
plt.figure(figsize=(10, 6))
df_clima['meanpressure'].plot()
plt.grid()

# %%
df_clima.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
#df_clima['date'] = pd.to_datetime(df_clima['date'])
#df_clima.set_index('date', inplace=True)

# %%
df_clima['humidity'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
decomposed = seasonal_decompose(
    df_clima['meantemp'], model='additive', period=7)
fig = decomposed.plot()
fig.set_size_inches((15, 10))
fig.tight_layout()
plt.show()

# %%
decomposed = seasonal_decompose(
    df_clima['meantemp'], model='additive', period=30)
fig = decomposed.plot()
fig.set_size_inches((15, 10))
fig.tight_layout()
plt.show()

# %%
decomposed = seasonal_decompose(
    df_clima['meantemp'], model='additive', period=180)
fig = decomposed.plot()
fig.set_size_inches((15, 10))
fig.tight_layout()
plt.show()

# %%
#Gráficos           
#plt.plot(df_clima['meantemp'])
plt.plot(df_clima['humidity'])
#plt.plot(df_clima['wind_speed'])

# %%
name = 'meantemp' #'meantemp' 'wind_speed' 'humidity'
#name = 'humidity'
#name = 'wind_speed'
result = adfuller(df_clima[name])


df_clima[name].plot()

print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Valores Críticos')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[1] < 0.05:
    print('É estacionário!')
else:
    print('Não é Estacionário!')

# %%
name = 'meantemp'

# %%
name_mod = name + '_mod'
df_clima[name_mod] = df_clima['meantemp'].apply(lambda x: np.log10(x))#cbrt(x))

# %%
df_clima['meantemp_mod'].plot()

# %%
result = adfuller(df_clima[name_mod])


df_clima[name_mod].plot()

print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Valores Críticos')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[1] < 0.05:
    print('É estacionário!')
else:
    print('Não é Estacionário!')

# %%
df_clima.meantemp

# %%
dados = df_clima.meantemp.diff(1)[1:]
dados.plot()

result = adfuller(dados)


#df_clima[name].plot()

print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Valores Críticos')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[1] < 0.05:
    print('É estacionário!')
else:
    print('Não é Estacionário!')

# %%
#plt.figure(figsize=(12, 8))
df_clima.meantemp[:'2013-05-20'].diff(1).plot()

# %%
df_clima.meantemp[:'2013-05-20'].plot()
